# %% [markdown]
# ### Import Packages

# %%
# Import packages

import glob
import csv
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2


sns.set_style('whitegrid')
sns.set(rc={"figure.figsize": (15, 8)})

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ### Append each .txt file into a DataFrame
# Each txt file is a row

# %%
# Iterate through each file name

main = pd.DataFrame()

for filename in glob.iglob('./training_set_a/*.txt'):
    
    # Open each file as data
    with open(filename) as inputfile:
        
        data = list(csv.reader(inputfile))                      # list of list
        data = pd.DataFrame(data[1:],columns=data[0])           # Convert list of list to DataFrame
        data.Value = data.Value.astype(float)                   # Change Value to float
        
        
        
        # Pivot_table to convert from long to wide dataset

        # Creation of new features - aggregate across the time series to find mean, min, max values
        # mean is chosen rather than median because we want to take into the account of 'outlier values'

        wide_data = pd.pivot_table(data,values=['Value'],columns='Parameter',aggfunc=[np.mean,np.min,np.max])
        wide_data.columns = wide_data.columns.droplevel(level=0)
        
        
        
        # rename new columns & lower capitalise
        new_columns = []

        for ind, col in enumerate(wide_data.columns):
    
            if ind < wide_data.columns.shape[0]/3:
                col = 'mean_'+col            
                new_columns.append(col)

            elif ind >= wide_data.columns.shape[0]/3 and ind < 2*wide_data.columns.shape[0]/3:
                col = 'min_'+col
                new_columns.append(col)

            else:
                col = 'max_'+col
                new_columns.append(col)
        
        wide_data.columns = new_columns
        wide_data.columns = wide_data.columns.str.lower()
        
        
        # rename descriptor row
        wide_data.rename(columns={'mean_age':'age','mean_gender':'gender','mean_height':'height',
                                    'mean_icutype':'icutype','mean_recordid':'recordid'},inplace=True)
            
        # drop min/max descriptor rows
        wide_data.drop(['min_age','max_age','min_gender','max_gender','min_height','max_height',
                          'min_icutype','max_icutype','min_recordid','max_recordid'],axis=1,inplace=True)
        
        # set recordid as index
        wide_data.set_index(['recordid'],inplace = True)
        
        main = main.append(wide_data)

# %%
# Open set a outcomes file as dataframe
with open('training_outcomes_a.txt') as outcomesfile:
        
        label = list(csv.reader(outcomesfile))                      # list of list
        label = pd.DataFrame(label[1:],columns=label[0])            # Convert list of list to DataFrame
        
        label = label.astype(float)                                 # Change all values to float
        label.columns = label.columns.str.lower()                   # Change all column to lowercase
        
        
        label.set_index(['recordid'],inplace = True)                # set recordid as index

# %%
# merge main data and label data
mortality = main.merge(label,how='outer',left_index=True,right_index=True)

# %%
mortality.head(5)
# Out:
#            age  gender  height  icutype  max_albumin  max_alp  max_alt  \
# recordid
# 132539.0  54.0     0.0    -1.0      4.0          NaN      NaN      NaN
# 132540.0  76.0     1.0   175.3      2.0          NaN      NaN      NaN
# 132541.0  44.0     0.0    -1.0      3.0          2.7    127.0     91.0
# 132543.0  68.0     1.0   180.3      3.0          4.4    105.0     12.0
# 132545.0  88.0     0.0    -1.0      3.0          3.3      NaN      NaN
#
#           max_ast  max_bilirubin  max_bun        ...          min_troponini  \
# recordid                                         ...
# 132539.0      NaN            NaN     13.0        ...                    NaN
# 132540.0      NaN            NaN     21.0        ...                    NaN
# 132541.0    235.0            3.0      8.0        ...                    NaN
# 132543.0     15.0            0.2     23.0        ...                    NaN
# 132545.0      NaN            NaN     45.0        ...                    NaN
#
#           min_troponint  min_urine  min_wbc  min_weight  saps-i  sofa  \
# recordid
# 132539.0            NaN        0.0      9.4        -1.0     6.0   1.0
# 132540.0            NaN        0.0      7.4        76.0    16.0   8.0
# 132541.0            NaN       18.0      3.7        56.7    21.0  11.0
# 132543.0            NaN      100.0      7.9        84.6     7.0   1.0
# 132545.0            NaN       16.0      3.8        -1.0    17.0   2.0
#
#           length_of_stay  survival  in-hospital_death
# recordid
# 132539.0             5.0      -1.0                0.0
# 132540.0             8.0      -1.0                0.0
# 132541.0            19.0      -1.0                0.0
# 132543.0             9.0     575.0                0.0
# 132545.0             4.0     918.0                0.0
#
# [5 rows x 120 columns]

# %% [markdown]
# RecordID (a unique integer for each ICU stay)
#
# Age (years)<br>
# Gender (0: female, or 1: male)<br>
# Height (cm)<br>
# ICUType (1: Coronary Care Unit, 2: Cardiac Surgery Recovery Unit, 3: Medical ICU, or 4: Surgical ICU)<br>
# Weight (kg)

# %% [markdown]
# Variables Description
#
# ALB Albumin (g/dL) <br>
# ALP Alkaline phosphatase (IU/L) <br>
# ALT Alanine transaminase (IU/L) <br>
# AST Aspartate transaminase (IU/L) <br>
# BIL Bilirubin (mg/dL) <br>
# BUN Blood urea nitrogen (mg/dL) <br>
# CHO Cholesterol (mg/dL) <br>
# CREA Serum creatinine (mg/dL) <br>
# DBP Invasive diastolic arterial blood pressure (mmHg) <br>
# FIO Fractional inspired O2 (0-1) <br>
# GCS Glasgow Coma Score (3-15) <br>
# GLU Serum glucose (mg/dL) <br>
# HCO Serum bicarbonate (mmol/L)  <br>
# HCT Hematocrit (%) <br>
# HR Heart rate (bpm) <br>
# K Serum potassium (mEq/L) <br>
# LAC Lactate (mmol/L) <br>
# MG Serum magnesium (mmol/L) <br>
# MAP Invasive mean arterial blood pressure (mmHg) <br>
# MEVE Mechanical ventilation respiration <br>
# NA Serum sodium (mEq/L) <br>
# NBP Non-invasive diastolic arterial blood pressure (mmHg) <br>
# NAP Non-invasive mean arterial blood pressure (mmHg) <br>
# NSP Non-invasive systolic arterial blood pressure (mmHg) <br>
# PCO partial pressure of arterial <br>
# CO2 (mmHg) <br>
# PO2 Partial pressure of arterial <br>
# O2 (mmHg) <br>
# PH Arterial pH (0-14) <br>
# PLA cells/nL RRA Respiration rate (bpm) <br>
# SO2 O2 saturation in hemoglobin (%) <br>
# SBP Invasive systolic arterial blood pressure (mmHg) <br>
# TEM Temperature (°C) <br>
# TRI Troponin-I (μg/L) <br>
# TRT Troponin-T (μg/L) <br>
# URI Urine output (mL) <br>
# WBC White blood cell count (cells/nL) <br>
# WEI kg <br>

# %%
# Open file

with open('./training_set_a/132539.txt') as inputfile:
    
    results = list(csv.reader(inputfile))           # Open file in list of list
    results = pd.DataFrame(results[1:],columns=results[0])     # Convert list of list to DataFrame
    results.Value = results.Value.astype(float)     # Change Value to float
    
results
# Out:
#       Time  Parameter      Value
# 0    00:00   RecordID  132539.00
# 1    00:00        Age      54.00
# 2    00:00     Gender       0.00
# 3    00:00     Height      -1.00
# 4    00:00    ICUType       4.00
# 5    00:00     Weight      -1.00
# 6    00:07        GCS      15.00
# 7    00:07         HR      73.00
# 8    00:07  NIDiasABP      65.00
# 9    00:07      NIMAP      92.33
# 10   00:07   NISysABP     147.00
# 11   00:07   RespRate      19.00
# 12   00:07       Temp      35.10
# 13   00:07      Urine     900.00
# 14   00:37         HR      77.00
# 15   00:37  NIDiasABP      58.00
# 16   00:37      NIMAP      91.00
# 17   00:37   NISysABP     157.00
# 18   00:37   RespRate      19.00
# 19   00:37       Temp      35.60
# 20   00:37      Urine      60.00
# 21   01:37         HR      60.00
# 22   01:37  NIDiasABP      62.00
# 23   01:37      NIMAP      87.00
# 24   01:37   NISysABP     137.00
# 25   01:37   RespRate      18.00
# 26   01:37      Urine      30.00
# 27   02:37         HR      62.00
# 28   02:37  NIDiasABP      52.00
# 29   02:37      NIMAP      75.67
# ..     ...        ...        ...
# 243  41:37   RespRate      14.00
# 244  41:37      Urine     450.00
# 245  42:37  NIDiasABP      67.00
# 246  42:37      NIMAP      87.67
# 247  42:37   NISysABP     129.00
# 248  42:37   RespRate      23.00
# 249  43:37        GCS      15.00
# 250  43:37         HR      73.00
# 251  43:37  NIDiasABP      64.00
# 252  43:37      NIMAP      82.67
# 253  43:37   NISysABP     120.00
# 254  43:37   RespRate      17.00
# 255  43:37       Temp      37.60
# 256  43:37      Urine     250.00
# 257  44:37   RespRate      20.00
# 258  45:37         HR      84.00
# 259  45:37  NIDiasABP      56.00
# 260  45:37      NIMAP      81.33
# 261  45:37   NISysABP     132.00
# 262  45:37   RespRate      20.00
# 263  45:37      Urine     300.00
# 264  46:37   RespRate      20.00
# 265  47:37        GCS      15.00
# 266  47:37         HR      86.00
# 267  47:37  NIDiasABP      55.00
# 268  47:37      NIMAP      79.33
# 269  47:37   NISysABP     128.00
# 270  47:37   RespRate      23.00
# 271  47:37       Temp      37.80
# 272  47:37      Urine     280.00
#
# [273 rows x 3 columns]

# %%
# Function to obtain the first data when admitted

def first_data(column):

    x = column.iloc[0]
    
    return x

# %%
def last_data(column):
    
    x = column.iloc[-1]

    return x

# %%
# Pivot_table to convert from long to wide dataset

# Creation of new features - aggregate across the time series to find mean, min, max values
# mean is chosen rather than median because we want to take into the account of 'outlier values'

wide_result = pd.pivot_table(results,values=['Value'],columns='Parameter',aggfunc=[np.mean,np.min,np.max,first_data,last_data])

wide_result.columns = wide_result.columns.droplevel(level=0)

# %%
pd.set_option('display.max_columns', 200)
wide_result
# Out:
# Parameter   Age   BUN  Creatinine        GCS  Gender  Glucose  HCO3   HCT  \
# Value      54.0  10.5        0.75  14.923077     0.0    160.0  27.0  32.5
#
# Parameter         HR  Height  ICUType    K   Mg  NIDiasABP      NIMAP  \
# Value      70.810811    -1.0      4.0  4.2  1.7  50.147059  71.559118
#
# Parameter    NISysABP     Na  Platelets  RecordID   RespRate       Temp  \
# Value      114.382353  136.5      203.0  132539.0  17.428571  37.357143
#
# Parameter       Urine   WBC  Weight   Age  BUN  Creatinine   GCS  Gender  \
# Value      171.052632  10.3    -1.0  54.0  8.0         0.7  14.0     0.0
#
# Parameter  Glucose  HCO3   HCT    HR  Height  ICUType    K   Mg  NIDiasABP  \
# Value        115.0  26.0  30.3  58.0    -1.0      4.0  4.0  1.5       39.0
#
# Parameter  NIMAP  NISysABP     Na  Platelets  RecordID  RespRate  Temp  Urine  \
# Value      58.67      96.0  136.0      185.0  132539.0      12.0  35.1    0.0
#
# Parameter  WBC  Weight   Age   BUN  Creatinine   GCS  Gender  Glucose  HCO3  \
# Value      9.4    -1.0  54.0  13.0         0.8  15.0     0.0    205.0  28.0
#
# Parameter   HCT    HR  Height  ICUType    K   Mg  NIDiasABP  NIMAP  NISysABP  \
# Value      33.7  86.0    -1.0      4.0  4.4  1.9       67.0  92.33     157.0
#
# Parameter     Na  Platelets  RecordID  RespRate  Temp  Urine   WBC  Weight  \
# Value      137.0      221.0  132539.0      24.0  38.2  900.0  11.2    -1.0
#
# Parameter   Age   BUN  Creatinine   GCS  Gender  Glucose  HCO3   HCT    HR  \
# Value      54.0  13.0         0.8  15.0     0.0    205.0  26.0  33.7  73.0
#
# Parameter  Height  ICUType    K   Mg  NIDiasABP  NIMAP  NISysABP     Na  \
# Value        -1.0      4.0  4.4  1.5       65.0  92.33     147.0  137.0
#
# Parameter  Platelets  RecordID  RespRate  Temp  Urine   WBC  Weight   Age  \
# Value          221.0  132539.0      19.0  35.1  900.0  11.2    -1.0  54.0
#
# Parameter  BUN  Creatinine   GCS  Gender  Glucose  HCO3   HCT    HR  Height  \
# Value      8.0         0.7  15.0     0.0    115.0  28.0  30.3  86.0    -1.0
#
# Parameter  ICUType    K   Mg  NIDiasABP  NIMAP  NISysABP     Na  Platelets  \
# Value          4.0  4.0  1.9       55.0  79.33     128.0  136.0      185.0
#
# Parameter  RecordID  RespRate  Temp  Urine  WBC  Weight
# Value      132539.0      23.0  37.8  280.0  9.4    -1.0

# %%
wide_result.columns.shape[0]
# Out:
# 120

# %%
for ind, col in enumerate(wide_result.columns):
    print ind,col
# Out:
# 0 Age
# 1 BUN
# 2 Creatinine
# 3 GCS
# 4 Gender
# 5 Glucose
# 6 HCO3
# 7 HCT
# 8 HR
# 9 Height
# 10 ICUType
# 11 K
# 12 Mg
# 13 NIDiasABP
# 14 NIMAP
# 15 NISysABP
# 16 Na
# 17 Platelets
# 18 RecordID
# 19 RespRate
# 20 Temp
# 21 Urine
# 22 WBC
# 23 Weight
# 24 Age
# 25 BUN
# 26 Creatinine
# 27 GCS
# 28 Gender
# 29 Glucose
# 30 HCO3
# 31 HCT
# 32 HR
# 33 Height
# 34 ICUType
# 35 K
# 36 Mg
# 37 NIDiasABP
# 38 NIMAP
# 39 NISysABP
# 40 Na
# 41 Platelets
# 42 RecordID
# 43 RespRate
# 44 Temp
# 45 Urine
# 46 WBC
# 47 Weight
# 48 Age
# 49 BUN
# 50 Creatinine
# 51 GCS
# 52 Gender
# 53 Glucose
# 54 HCO3
# 55 HCT
# 56 HR
# 57 Height
# 58 ICUType
# 59 K
# 60 Mg
# 61 NIDiasABP
# 62 NIMAP
# 63 NISysABP
# 64 Na
# 65 Platelets
# 66 RecordID
# 67 RespRate
# 68 Temp
# 69 Urine
# 70 WBC
# 71 Weight
# 72 Age
# 73 BUN
# 74 Creatinine
# 75 GCS
# 76 Gender
# 77 Glucose
# 78 HCO3
# 79 HCT
# 80 HR
# 81 Height
# 82 ICUType
# 83 K
# 84 Mg
# 85 NIDiasABP
# 86 NIMAP
# 87 NISysABP
# 88 Na
# 89 Platelets
# 90 RecordID
# 91 RespRate
# 92 Temp
# 93 Urine
# 94 WBC
# 95 Weight
# 96 Age
# 97 BUN
# 98 Creatinine
# 99 GCS
# 100 Gender
# 101 Glucose
# 102 HCO3
# 103 HCT
# 104 HR
# 105 Height
# 106 ICUType
# 107 K
# 108 Mg
# 109 NIDiasABP
# 110 NIMAP
# 111 NISysABP
# 112 Na
# 113 Platelets
# 114 RecordID
# 115 RespRate
# 116 Temp
# 117 Urine
# 118 WBC
# 119 Weight

# %%
new_columns = []

for ind, col in enumerate(wide_result.columns):
    
    if ind < wide_result.columns.shape[0]/5:
        col = 'mean_'+col            
        new_columns.append(col)

    elif ind >= wide_result.columns.shape[0]/5 and ind < 2*(wide_result.columns.shape[0]/5):
        col = 'min_'+col
        new_columns.append(col)
        
    elif ind >= 2*(wide_result.columns.shape[0]/5) and ind < 3*(wide_result.columns.shape[0]/5):
        col = 'max_'+col
        new_columns.append(col)
        
    elif ind >= 3*(wide_result.columns.shape[0]/5) and ind < 4*(wide_result.columns.shape[0]/5):
        col = 'first_'+col
        new_columns.append(col)

    else:
        col = 'last_'+col
        new_columns.append(col)
        
print new_columns
# Out:
# ['mean_Age', 'mean_BUN', 'mean_Creatinine', 'mean_GCS', 'mean_Gender', 'mean_Glucose', 'mean_HCO3', 'mean_HCT', 'mean_HR', 'mean_Height', 'mean_ICUType', 'mean_K', 'mean_Mg', 'mean_NIDiasABP', 'mean_NIMAP', 'mean_NISysABP', 'mean_Na', 'mean_Platelets', 'mean_RecordID', 'mean_RespRate', 'mean_Temp', 'mean_Urine', 'mean_WBC', 'mean_Weight', 'min_Age', 'min_BUN', 'min_Creatinine', 'min_GCS', 'min_Gender', 'min_Glucose', 'min_HCO3', 'min_HCT', 'min_HR', 'min_Height', 'min_ICUType', 'min_K', 'min_Mg', 'min_NIDiasABP', 'min_NIMAP', 'min_NISysABP', 'min_Na', 'min_Platelets', 'min_RecordID', 'min_RespRate', 'min_Temp', 'min_Urine', 'min_WBC', 'min_Weight', 'max_Age', 'max_BUN', 'max_Creatinine', 'max_GCS', 'max_Gender', 'max_Glucose', 'max_HCO3', 'max_HCT', 'max_HR', 'max_Height', 'max_ICUType', 'max_K', 'max_Mg', 'max_NIDiasABP', 'max_NIMAP', 'max_NISysABP', 'max_Na', 'max_Platelets', 'max_RecordID', 'max_RespRate', 'max_Temp', 'max_Urine', 'max_WBC', 'max_Weight', 'first_Age', 'first_BUN', 'first_Creatinine', 'first_GCS', 'first_Gender', 'first_Glucose', 'first_HCO3', 'first_HCT', 'first_HR', 'first_Height', 'first_ICUType', 'first_K', 'first_Mg', 'first_NIDiasABP', 'first_NIMAP', 'first_NISysABP', 'first_Na', 'first_Platelets', 'first_RecordID', 'first_RespRate', 'first_Temp', 'first_Urine', 'first_WBC', 'first_Weight', 'last_Age', 'last_BUN', 'last_Creatinine', 'last_GCS', 'last_Gender', 'last_Glucose', 'last_HCO3', 'last_HCT', 'last_HR', 'last_Height', 'last_ICUType', 'last_K', 'last_Mg', 'last_NIDiasABP', 'last_NIMAP', 'last_NISysABP', 'last_Na', 'last_Platelets', 'last_RecordID', 'last_RespRate', 'last_Temp', 'last_Urine', 'last_WBC', 'last_Weight']

# %%
# rename the columns and lower capitalise

#new_columns = [u'Age', u'mean_BUN', u'mean_Creatinine', u'mean_GCS', u'Gender', u'mean_Glucose', u'mean_HCO3',
 #      u'mean_HCT', u'mean_HR', u'Height', u'ICUType', u'mean_K', u'mean_Mg', u'mean_NIDiasABP',
  #     u'mean_NIMAP', u'mean_NISysABP', u'mean_Na', u'mean_Platelets', u'RecordID', u'mean_RespRate',
   #    u'mean_Temp', u'mean_Urine', u'mean_WBC', u'mean_Weight', u'min_Age', u'min_BUN', u'min_Creatinine',
    #   u'min_GCS', u'min_Gender', u'min_Glucose', u'min_HCO3', u'min_HCT', u'min_HR', u'min_Height',
     #  u'min_ICUType', u'min_K', u'min_Mg', u'min_NIDiasABP', u'min_NIMAP', u'min_NISysABP', u'min_Na',
      # u'min_Platelets', u'min_RecordID', u'min_RespRate', u'min_Temp', u'min_Urine', u'min_WBC',
       #u'min_Weight', u'max_Age', u'max_BUN', u'max_Creatinine', u'max_GCS', u'max_Gender', u'max_Glucose',
       #u'max_HCO3', u'max_HCT', u'max_HR', u'max_Height', u'max_ICUType', u'max_K', u'max_Mg',
       #u'max_NIDiasABP', u'max_NIMAP', u'max_NISysABP', u'max_Na', u'max_Platelets', u'max_RecordID',
       #u'max_RespRate', u'max_Temp', u'max_Urine', u'max_WBC', u'max_Weight']
wide_result.columns = new_columns
wide_result.columns = wide_result.columns.str.lower()

# %%
pd.set_option('display.max_columns', 200,'display.max_info_rows',200)
print list(wide_result.columns)
# Out:
# ['mean_age', 'mean_bun', 'mean_creatinine', 'mean_gcs', 'mean_gender', 'mean_glucose', 'mean_hco3', 'mean_hct', 'mean_hr', 'mean_height', 'mean_icutype', 'mean_k', 'mean_mg', 'mean_nidiasabp', 'mean_nimap', 'mean_nisysabp', 'mean_na', 'mean_platelets', 'mean_recordid', 'mean_resprate', 'mean_temp', 'mean_urine', 'mean_wbc', 'mean_weight', 'min_age', 'min_bun', 'min_creatinine', 'min_gcs', 'min_gender', 'min_glucose', 'min_hco3', 'min_hct', 'min_hr', 'min_height', 'min_icutype', 'min_k', 'min_mg', 'min_nidiasabp', 'min_nimap', 'min_nisysabp', 'min_na', 'min_platelets', 'min_recordid', 'min_resprate', 'min_temp', 'min_urine', 'min_wbc', 'min_weight', 'max_age', 'max_bun', 'max_creatinine', 'max_gcs', 'max_gender', 'max_glucose', 'max_hco3', 'max_hct', 'max_hr', 'max_height', 'max_icutype', 'max_k', 'max_mg', 'max_nidiasabp', 'max_nimap', 'max_nisysabp', 'max_na', 'max_platelets', 'max_recordid', 'max_resprate', 'max_temp', 'max_urine', 'max_wbc', 'max_weight', 'first_age', 'first_bun', 'first_creatinine', 'first_gcs', 'first_gender', 'first_glucose', 'first_hco3', 'first_hct', 'first_hr', 'first_height', 'first_icutype', 'first_k', 'first_mg', 'first_nidiasabp', 'first_nimap', 'first_nisysabp', 'first_na', 'first_platelets', 'first_recordid', 'first_resprate', 'first_temp', 'first_urine', 'first_wbc', 'first_weight', 'last_age', 'last_bun', 'last_creatinine', 'last_gcs', 'last_gender', 'last_glucose', 'last_hco3', 'last_hct', 'last_hr', 'last_height', 'last_icutype', 'last_k', 'last_mg', 'last_nidiasabp', 'last_nimap', 'last_nisysabp', 'last_na', 'last_platelets', 'last_recordid', 'last_resprate', 'last_temp', 'last_urine', 'last_wbc', 'last_weight']

# %%
wide_result.head()
# Out:
#        mean_age  mean_bun  mean_creatinine   mean_gcs  mean_gender  \
# Value      54.0      10.5             0.75  14.923077          0.0
#
#        mean_glucose  mean_hco3  mean_hct    mean_hr  mean_height  \
# Value         160.0       27.0      32.5  70.810811         -1.0
#
#        mean_icutype  mean_k  mean_mg  mean_nidiasabp  mean_nimap  \
# Value           4.0     4.2      1.7       50.147059   71.559118
#
#        mean_nisysabp  mean_na  mean_platelets  mean_recordid  mean_resprate  \
# Value     114.382353    136.5           203.0       132539.0      17.428571
#
#        mean_temp  mean_urine  mean_wbc  mean_weight  min_age  min_bun  \
# Value  37.357143  171.052632      10.3         -1.0     54.0      8.0
#
#        min_creatinine  min_gcs  min_gender  min_glucose  min_hco3  min_hct  \
# Value             0.7     14.0         0.0        115.0      26.0     30.3
#
#        min_hr  min_height  min_icutype  min_k  min_mg  min_nidiasabp  \
# Value    58.0        -1.0          4.0    4.0     1.5           39.0
#
#        min_nimap  min_nisysabp  min_na  min_platelets  min_recordid  \
# Value      58.67          96.0   136.0          185.0      132539.0
#
#        min_resprate  min_temp  min_urine  min_wbc  min_weight  max_age  \
# Value          12.0      35.1        0.0      9.4        -1.0     54.0
#
#        max_bun  max_creatinine  max_gcs  max_gender  max_glucose  max_hco3  \
# Value     13.0             0.8     15.0         0.0        205.0      28.0
#
#        max_hct  max_hr  max_height  max_icutype  max_k  max_mg  max_nidiasabp  \
# Value     33.7    86.0        -1.0          4.0    4.4     1.9           67.0
#
#        max_nimap  max_nisysabp  max_na  max_platelets  max_recordid  \
# Value      92.33         157.0   137.0          221.0      132539.0
#
#        max_resprate  max_temp  max_urine  max_wbc  max_weight  first_age  \
# Value          24.0      38.2      900.0     11.2        -1.0       54.0
#
#        first_bun  first_creatinine  first_gcs  first_gender  first_glucose  \
# Value       13.0               0.8       15.0           0.0          205.0
#
#        first_hco3  first_hct  first_hr  first_height  first_icutype  first_k  \
# Value        26.0       33.7      73.0          -1.0            4.0      4.4
#
#        first_mg  first_nidiasabp  first_nimap  first_nisysabp  first_na  \
# Value       1.5             65.0        92.33           147.0     137.0
#
#        first_platelets  first_recordid  first_resprate  first_temp  \
# Value            221.0        132539.0            19.0        35.1
#
#        first_urine  first_wbc  first_weight  last_age  last_bun  \
# Value        900.0       11.2          -1.0      54.0       8.0
#
#        last_creatinine  last_gcs  last_gender  last_glucose  last_hco3  \
# Value              0.7      15.0          0.0         115.0       28.0
#
#        last_hct  last_hr  last_height  last_icutype  last_k  last_mg  \
# Value      30.3     86.0         -1.0           4.0     4.0      1.9
#
#        last_nidiasabp  last_nimap  last_nisysabp  last_na  last_platelets  \
# Value            55.0       79.33          128.0    136.0           185.0
#
#        last_recordid  last_resprate  last_temp  last_urine  last_wbc  \
# Value       132539.0           23.0       37.8       280.0       9.4
#
#        last_weight
# Value         -1.0

# %%
# rename descriptor row
wide_result.rename(columns={'mean_age':'age','mean_gender':'gender','mean_height':'height',
                   'mean_icutype':'icutype','mean_recordid':'recordid'},inplace=True)

# %%
for col in wide_result.columns:
    print col
# Out:
# age
# mean_bun
# mean_creatinine
# mean_gcs
# gender
# mean_glucose
# mean_hco3
# mean_hct
# mean_hr
# height
# icutype
# mean_k
# mean_mg
# mean_nidiasabp
# mean_nimap
# mean_nisysabp
# mean_na
# mean_platelets
# recordid
# mean_resprate
# mean_temp
# mean_urine
# mean_wbc
# mean_weight
# min_age
# min_bun
# min_creatinine
# min_gcs
# min_gender
# min_glucose
# min_hco3
# min_hct
# min_hr
# min_height
# min_icutype
# min_k
# min_mg
# min_nidiasabp
# min_nimap
# min_nisysabp
# min_na
# min_platelets
# min_recordid
# min_resprate
# min_temp
# min_urine
# min_wbc
# min_weight
# max_age
# max_bun
# max_creatinine
# max_gcs
# max_gender
# max_glucose
# max_hco3
# max_hct
# max_hr
# max_height
# max_icutype
# max_k
# max_mg
# max_nidiasabp
# max_nimap
# max_nisysabp
# max_na
# max_platelets
# max_recordid
# max_resprate
# max_temp
# max_urine
# max_wbc
# max_weight
# first_age
# first_bun
# first_creatinine
# first_gcs
# first_gender
# first_glucose
# first_hco3
# first_hct
# first_hr
# first_height
# first_icutype
# first_k
# first_mg
# first_nidiasabp
# first_nimap
# first_nisysabp
# first_na
# first_platelets
# first_recordid
# first_resprate
# first_temp
# first_urine
# first_wbc
# first_weight
# last_age
# last_bun
# last_creatinine
# last_gcs
# last_gender
# last_glucose
# last_hco3
# last_hct
# last_hr
# last_height
# last_icutype
# last_k
# last_mg
# last_nidiasabp
# last_nimap
# last_nisysabp
# last_na
# last_platelets
# last_recordid
# last_resprate
# last_temp
# last_urine
# last_wbc
# last_weight

# %%
str(list(wide_result.columns))
# Out:
# "['age', 'mean_bun', 'mean_creatinine', 'mean_gcs', 'gender', 'mean_glucose', 'mean_hco3', 'mean_hct', 'mean_hr', 'height', 'icutype', 'mean_k', 'mean_mg', 'mean_nidiasabp', 'mean_nimap', 'mean_nisysabp', 'mean_na', 'mean_platelets', 'recordid', 'mean_resprate', 'mean_temp', 'mean_urine', 'mean_wbc', 'mean_weight', 'min_age', 'min_bun', 'min_creatinine', 'min_gcs', 'min_gender', 'min_glucose', 'min_hco3', 'min_hct', 'min_hr', 'min_height', 'min_icutype', 'min_k', 'min_mg', 'min_nidiasabp', 'min_nimap', 'min_nisysabp', 'min_na', 'min_platelets', 'min_recordid', 'min_resprate', 'min_temp', 'min_urine', 'min_wbc', 'min_weight', 'max_age', 'max_bun', 'max_creatinine', 'max_gcs', 'max_gender', 'max_glucose', 'max_hco3', 'max_hct', 'max_hr', 'max_height', 'max_icutype', 'max_k', 'max_mg', 'max_nidiasabp', 'max_nimap', 'max_nisysabp', 'max_na', 'max_platelets', 'max_recordid', 'max_resprate', 'max_temp', 'max_urine', 'max_wbc', 'max_weight', 'first_age', 'first_bun', 'first_creatinine', 'first_gcs', 'first_gender', 'first_glucose', 'first_hco3', 'first_hct', 'first_hr', 'first_height', 'first_icutype', 'first_k', 'first_mg', 'first_nidiasabp', 'first_nimap', 'first_nisysabp', 'first_na', 'first_platelets', 'first_recordid', 'first_resprate', 'first_temp', 'first_urine', 'first_wbc', 'first_weight', 'last_age', 'last_bun', 'last_creatinine', 'last_gcs', 'last_gender', 'last_glucose', 'last_hco3', 'last_hct', 'last_hr', 'last_height', 'last_icutype', 'last_k', 'last_mg', 'last_nidiasabp', 'last_nimap', 'last_nisysabp', 'last_na', 'last_platelets', 'last_recordid', 'last_resprate', 'last_temp', 'last_urine', 'last_wbc', 'last_weight']"

# %%
import re

drop_col = wide_result.columns[wide_result.columns.str.contains(
    '(\w+_age)|(\w+_height)|(\w+_gender)|(\w+_icutype)|(\w+_recordid)')]
# Out:
# /Users/joannasyeow/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.

# %%
drop_col
# Out:
# Index([u'min_age', u'min_gender', u'min_height', u'min_icutype',
#        u'min_recordid', u'max_age', u'max_gender', u'max_height',
#        u'max_icutype', u'max_recordid', u'first_age', u'first_gender',
#        u'first_height', u'first_icutype', u'first_recordid', u'last_age',
#        u'last_gender', u'last_height', u'last_icutype', u'last_recordid'],
#       dtype='object')

# %%
# drop descriptor rows

wide_result.drop(drop_col,axis=1,inplace=True)

# %%
wide_result.columns
# Out:
# Index([u'age', u'mean_bun', u'mean_creatinine', u'mean_gcs', u'gender',
#        u'mean_glucose', u'mean_hco3', u'mean_hct', u'mean_hr', u'height',
#        u'icutype', u'mean_k', u'mean_mg', u'mean_nidiasabp', u'mean_nimap',
#        u'mean_nisysabp', u'mean_na', u'mean_platelets', u'recordid',
#        u'mean_resprate', u'mean_temp', u'mean_urine', u'mean_wbc',
#        u'mean_weight', u'min_bun', u'min_creatinine', u'min_gcs',
#        u'min_glucose', u'min_hco3', u'min_hct', u'min_hr', u'min_k', u'min_mg',
#        u'min_nidiasabp', u'min_nimap', u'min_nisysabp', u'min_na',
#        u'min_platelets', u'min_resprate', u'min_temp', u'min_urine',
#        u'min_wbc', u'min_weight', u'max_bun', u'max_creatinine', u'max_gcs',
#        u'max_glucose', u'max_hco3', u'max_hct', u'max_hr', u'max_k', u'max_mg',
#        u'max_nidiasabp', u'max_nimap', u'max_nisysabp', u'max_na',
#        u'max_platelets', u'max_resprate', u'max_temp', u'max_urine',
#        u'max_wbc', u'max_weight', u'first_bun', u'first_creatinine',
#        u'first_gcs', u'first_glucose', u'first_hco3', u'first_hct',
#        u'first_hr', u'first_k', u'first_mg', u'first_nidiasabp',
#        u'first_nimap', u'first_nisysabp', u'first_na', u'first_platelets',
#        u'first_resprate', u'first_temp', u'first_urine', u'first_wbc',
#        u'first_weight', u'last_bun', u'last_creatinine', u'last_gcs',
#        u'last_glucose', u'last_hco3', u'last_hct', u'last_hr', u'last_k',
#        u'last_mg', u'last_nidiasabp', u'last_nimap', u'last_nisysabp',
#        u'last_na', u'last_platelets', u'last_resprate', u'last_temp',
#        u'last_urine', u'last_wbc', u'last_weight'],
#       dtype='object')

# %%
wide_result.set_index(['recordid'],inplace = True)

# %%
wide_result
# Out:
#            age  mean_bun  mean_creatinine   mean_gcs  gender  mean_glucose  \
# recordid
# 132539.0  54.0      10.5             0.75  14.923077     0.0         160.0
#
#           mean_hco3  mean_hct    mean_hr  height  icutype  mean_k  mean_mg  \
# recordid
# 132539.0       27.0      32.5  70.810811    -1.0      4.0     4.2      1.7
#
#           mean_nidiasabp  mean_nimap  mean_nisysabp  mean_na  mean_platelets  \
# recordid
# 132539.0       50.147059   71.559118     114.382353    136.5           203.0
#
#           mean_resprate  mean_temp  mean_urine  mean_wbc  mean_weight  \
# recordid
# 132539.0      17.428571  37.357143  171.052632      10.3         -1.0
#
#           min_bun  min_creatinine  min_gcs  min_glucose  min_hco3  min_hct  \
# recordid
# 132539.0      8.0             0.7     14.0        115.0      26.0     30.3
#
#           min_hr  min_k  min_mg  min_nidiasabp  min_nimap  min_nisysabp  \
# recordid
# 132539.0    58.0    4.0     1.5           39.0      58.67          96.0
#
#           min_na  min_platelets  min_resprate  min_temp  min_urine  min_wbc  \
# recordid
# 132539.0   136.0          185.0          12.0      35.1        0.0      9.4
#
#           min_weight  max_bun  max_creatinine  max_gcs  max_glucose  max_hco3  \
# recordid
# 132539.0        -1.0     13.0             0.8     15.0        205.0      28.0
#
#           max_hct  max_hr  max_k  max_mg  max_nidiasabp  max_nimap  \
# recordid
# 132539.0     33.7    86.0    4.4     1.9           67.0      92.33
#
#           max_nisysabp  max_na  max_platelets  max_resprate  max_temp  \
# recordid
# 132539.0         157.0   137.0          221.0          24.0      38.2
#
#           max_urine  max_wbc  max_weight  first_bun  first_creatinine  \
# recordid
# 132539.0      900.0     11.2        -1.0       13.0               0.8
#
#           first_gcs  first_glucose  first_hco3  first_hct  first_hr  first_k  \
# recordid
# 132539.0       15.0          205.0        26.0       33.7      73.0      4.4
#
#           first_mg  first_nidiasabp  first_nimap  first_nisysabp  first_na  \
# recordid
# 132539.0       1.5             65.0        92.33           147.0     137.0
#
#           first_platelets  first_resprate  first_temp  first_urine  first_wbc  \
# recordid
# 132539.0            221.0            19.0        35.1        900.0       11.2
#
#           first_weight  last_bun  last_creatinine  last_gcs  last_glucose  \
# recordid
# 132539.0          -1.0       8.0              0.7      15.0         115.0
#
#           last_hco3  last_hct  last_hr  last_k  last_mg  last_nidiasabp  \
# recordid
# 132539.0       28.0      30.3     86.0     4.0      1.9            55.0
#
#           last_nimap  last_nisysabp  last_na  last_platelets  last_resprate  \
# recordid
# 132539.0       79.33          128.0    136.0           185.0           23.0
#
#           last_temp  last_urine  last_wbc  last_weight
# recordid
# 132539.0       37.8       280.0       9.4         -1.0

# %%
main = pd.DataFrame()

# %%
main = main.append(wide_result)

# %%
main
# Out:
#            age  mean_bun  mean_creatinine   mean_gcs  gender  mean_glucose  \
# recordid
# 132539.0  54.0      10.5             0.75  14.923077     0.0         160.0
#
#           mean_hco3  mean_hct    mean_hr  height  icutype  mean_k  mean_mg  \
# recordid
# 132539.0       27.0      32.5  70.810811    -1.0      4.0     4.2      1.7
#
#           mean_nidiasabp  mean_nimap  mean_nisysabp  mean_na  mean_platelets  \
# recordid
# 132539.0       50.147059   71.559118     114.382353    136.5           203.0
#
#           mean_resprate  mean_temp  mean_urine  mean_wbc  mean_weight  \
# recordid
# 132539.0      17.428571  37.357143  171.052632      10.3         -1.0
#
#           min_bun  min_creatinine  min_gcs  min_glucose  min_hco3  min_hct  \
# recordid
# 132539.0      8.0             0.7     14.0        115.0      26.0     30.3
#
#           min_hr  min_k  min_mg  min_nidiasabp  min_nimap  min_nisysabp  \
# recordid
# 132539.0    58.0    4.0     1.5           39.0      58.67          96.0
#
#           min_na  min_platelets  min_resprate  min_temp  min_urine  min_wbc  \
# recordid
# 132539.0   136.0          185.0          12.0      35.1        0.0      9.4
#
#           min_weight  max_bun  max_creatinine  max_gcs  max_glucose  max_hco3  \
# recordid
# 132539.0        -1.0     13.0             0.8     15.0        205.0      28.0
#
#           max_hct  max_hr  max_k  max_mg  max_nidiasabp  max_nimap  \
# recordid
# 132539.0     33.7    86.0    4.4     1.9           67.0      92.33
#
#           max_nisysabp  max_na  max_platelets  max_resprate  max_temp  \
# recordid
# 132539.0         157.0   137.0          221.0          24.0      38.2
#
#           max_urine  max_wbc  max_weight  first_bun  first_creatinine  \
# recordid
# 132539.0      900.0     11.2        -1.0       13.0               0.8
#
#           first_gcs  first_glucose  first_hco3  first_hct  first_hr  first_k  \
# recordid
# 132539.0       15.0          205.0        26.0       33.7      73.0      4.4
#
#           first_mg  first_nidiasabp  first_nimap  first_nisysabp  first_na  \
# recordid
# 132539.0       1.5             65.0        92.33           147.0     137.0
#
#           first_platelets  first_resprate  first_temp  first_urine  first_wbc  \
# recordid
# 132539.0            221.0            19.0        35.1        900.0       11.2
#
#           first_weight  last_bun  last_creatinine  last_gcs  last_glucose  \
# recordid
# 132539.0          -1.0       8.0              0.7      15.0         115.0
#
#           last_hco3  last_hct  last_hr  last_k  last_mg  last_nidiasabp  \
# recordid
# 132539.0       28.0      30.3     86.0     4.0      1.9            55.0
#
#           last_nimap  last_nisysabp  last_na  last_platelets  last_resprate  \
# recordid
# 132539.0       79.33          128.0    136.0           185.0           23.0
#
#           last_temp  last_urine  last_wbc  last_weight
# recordid
# 132539.0       37.8       280.0       9.4         -1.0

# %%
# Open each file as result
with open('./training_set_a/132598.txt') as inputfile:
        
    data = list(csv.reader(inputfile))                      # list of list
    data = pd.DataFrame(data[1:],columns=data[0])     # Convert list of list to DataFrame
    data.Value = data.Value.astype(float)                   # Change Value to float
        
        
        
        # Pivot_table to convert from long to wide dataset

        # Creation of new features - aggregate across the time series to find mean, min, max values
        # mean is chosen rather than median because we want to take into the account of 'outlier values'

    wide_data = pd.pivot_table(data,values=['Value'],columns='Parameter',aggfunc=[np.mean,np.min,np.max])
    wide_data.columns = wide_data.columns.droplevel(level=0)
        
        
        
        # rename new columns & lower capitalise
    new_columns = []

    for ind, col in enumerate(wide_data.columns):
    
        if ind < wide_data.columns.shape[0]/3:   
            col = 'mean_'+col            
            new_columns.append(col)

        elif ind >= wide_data.columns.shape[0]/3 and ind < 2*wide_data.columns.shape[0]/3:
            col = 'min_'+col
            new_columns.append(col)

        else:
            col = 'max_'+col
            new_columns.append(col)
        
    wide_data.columns = new_columns
    wide_data.columns = wide_data.columns.str.lower()
        
        
        # rename descriptor row
    wide_data.rename(columns={'mean_age':'age','mean_gender':'gender','mean_height':'height',
                                    'mean_icutype':'icutype','mean_recordid':'recordid'},inplace=True)
            
        # drop min/max descriptor rows
    wide_data.drop(['min_age','max_age','min_gender','max_gender','min_height','max_height',
                          'min_icutype','max_icutype','min_recordid','max_recordid'],axis=1,inplace=True)
        
        # set recordid as index
    wide_data.set_index(['recordid'],inplace = True)

# %%
main = main.append(wide_data)

# %%
main
# Out:
#            age  first_bun  first_creatinine  first_gcs  first_glucose  \
# recordid
# 132539.0  54.0       13.0               0.8       15.0          205.0
# 132599.0  53.0        NaN               NaN        NaN            NaN
# 132599.0  53.0        NaN               NaN        NaN            NaN
# 132598.0  80.0        NaN               NaN        NaN            NaN
#
#           first_hco3  first_hct  first_hr  first_k  first_mg  first_na  \
# recordid
# 132539.0        26.0       33.7      73.0      4.4       1.5     137.0
# 132599.0         NaN        NaN       NaN      NaN       NaN       NaN
# 132599.0         NaN        NaN       NaN      NaN       NaN       NaN
# 132598.0         NaN        NaN       NaN      NaN       NaN       NaN
#
#           first_nidiasabp  first_nimap  first_nisysabp  first_platelets  \
# recordid
# 132539.0             65.0        92.33           147.0            221.0
# 132599.0              NaN          NaN             NaN              NaN
# 132599.0              NaN          NaN             NaN              NaN
# 132598.0              NaN          NaN             NaN              NaN
#
#           first_resprate  first_temp  first_urine  first_wbc  first_weight  \
# recordid
# 132539.0            19.0        35.1        900.0       11.2          -1.0
# 132599.0             NaN         NaN          NaN        NaN           NaN
# 132599.0             NaN         NaN          NaN        NaN           NaN
# 132598.0             NaN         NaN          NaN        NaN           NaN
#
#           gender  height  icutype  last_bun  last_creatinine  last_gcs  \
# recordid
# 132539.0     0.0    -1.0      4.0       8.0              0.7      15.0
# 132599.0     0.0   177.8      4.0       NaN              NaN       NaN
# 132599.0     0.0   177.8      4.0       NaN              NaN       NaN
# 132598.0     0.0    -1.0      4.0       NaN              NaN       NaN
#
#           last_glucose  last_hco3  last_hct  last_hr  last_k  last_mg  \
# recordid
# 132539.0         115.0       28.0      30.3     86.0     4.0      1.9
# 132599.0           NaN        NaN       NaN      NaN     NaN      NaN
# 132599.0           NaN        NaN       NaN      NaN     NaN      NaN
# 132598.0           NaN        NaN       NaN      NaN     NaN      NaN
#
#           last_na  last_nidiasabp  last_nimap  last_nisysabp  last_platelets  \
# recordid
# 132539.0    136.0            55.0       79.33          128.0           185.0
# 132599.0      NaN             NaN         NaN            NaN             NaN
# 132599.0      NaN             NaN         NaN            NaN             NaN
# 132598.0      NaN             NaN         NaN            NaN             NaN
#
#           last_resprate  last_temp  last_urine  last_wbc  last_weight  \
# recordid
# 132539.0           23.0       37.8       280.0       9.4         -1.0
# 132599.0            NaN        NaN         NaN       NaN          NaN
# 132599.0            NaN        NaN         NaN       NaN          NaN
# 132598.0            NaN        NaN         NaN       NaN          NaN
#
#           max_albumin  max_alp  max_alt  max_ast  max_bilirubin  max_bun  \
# recordid
# 132539.0          NaN      NaN      NaN      NaN            NaN     13.0
# 132599.0          2.0    124.0     14.0     20.0            2.0     33.0
# 132599.0          2.0    124.0     14.0     20.0            2.0     33.0
# 132598.0          NaN      NaN      NaN      NaN            NaN     30.0
#
#           max_creatinine  max_diasabp  max_fio2  max_gcs  max_glucose  \
# recordid
# 132539.0             0.8          NaN       NaN     15.0        205.0
# 132599.0             1.0         83.0       1.0     14.0        150.0
# 132599.0             1.0         83.0       1.0     14.0        150.0
# 132598.0             1.0         98.0       1.0      8.0        201.0
#
#           max_hco3  max_hct  max_hr  max_k  max_lactate  max_map  \
# recordid
# 132539.0      28.0     33.7    86.0    4.4          NaN      NaN
# 132599.0      23.0     26.8   104.0    3.7          2.1    102.0
# 132599.0      23.0     26.8   104.0    3.7          2.1    102.0
# 132598.0      28.0     40.9   158.0    4.0          NaN    132.0
#
#           max_mechvent  max_mg  max_na  max_nidiasabp  max_nimap  \
# recordid
# 132539.0           NaN     1.9   137.0           67.0      92.33
# 132599.0           1.0     2.3   139.0           69.0      86.00
# 132599.0           1.0     2.3   139.0           69.0      86.00
# 132598.0           1.0     2.3   146.0          115.0     127.30
#
#           max_nisysabp  max_paco2  max_pao2  max_ph  max_platelets  \
# recordid
# 132539.0         157.0        NaN       NaN     NaN          221.0
# 132599.0         119.0       38.0     184.0    7.51          255.0
# 132599.0         119.0       38.0     184.0    7.51          255.0
# 132598.0         176.0       31.0     364.0    7.52          246.0
#
#           max_resprate  max_sao2  max_sysabp  max_temp  max_troponint  \
# recordid
# 132539.0          24.0       NaN         NaN      38.2            NaN
# 132599.0           NaN      98.0       145.0      38.6           0.02
# 132599.0           NaN      98.0       145.0      38.6           0.02
# 132598.0           NaN      99.0       208.0      39.4            NaN
#
#           max_urine  max_wbc  max_weight  mean_albumin    mean_alp   mean_alt  \
# recordid
# 132539.0      900.0     11.2        -1.0           NaN         NaN        NaN
# 132599.0      400.0     14.2        73.5           2.0  117.333333  13.333333
# 132599.0      400.0     14.2        73.5           2.0  117.333333  13.333333
# 132598.0      400.0     20.2        60.0           NaN         NaN        NaN
#
#            mean_ast  mean_bilirubin   mean_bun  mean_creatinine  mean_diasabp  \
# recordid
# 132539.0        NaN             NaN  10.500000         0.750000           NaN
# 132599.0  19.666667        1.633333  23.250000         0.650000     67.557692
# 132599.0  19.666667        1.633333  23.250000         0.650000     67.557692
# 132598.0        NaN             NaN  23.666667         0.833333     68.464789
#
#           mean_fio2   mean_gcs  mean_glucose  mean_hco3  mean_hct    mean_hr  \
# recordid
# 132539.0        NaN  14.923077    160.000000  27.000000     32.50  70.810811
# 132599.0    0.56000   8.416667    109.500000  22.000000     25.15  85.392857
# 132599.0    0.56000   8.416667    109.500000  22.000000     25.15  85.392857
# 132598.0    0.49375   7.173913    156.333333  23.333333     36.85  78.708861
#
#           mean_k  mean_lactate   mean_map  mean_mechvent   mean_mg  \
# recordid
# 132539.0   4.200           NaN        NaN            NaN  1.700000
# 132599.0   3.675           1.8  82.788462            1.0  2.050000
# 132599.0   3.675           1.8  82.788462            1.0  2.050000
# 132598.0   3.675           NaN  95.478873            1.0  2.033333
#
#              mean_na  mean_nidiasabp  mean_nimap  mean_nisysabp  mean_paco2  \
# recordid
# 132539.0  136.500000       50.147059   71.559118     114.382353         NaN
# 132599.0  137.000000       63.000000   79.500000     109.000000   32.142857
# 132599.0  137.000000       63.000000   79.500000     109.000000   32.142857
# 132598.0  142.666667       66.767442   89.037674     133.581395   28.285714
#
#            mean_pao2   mean_ph  mean_platelets  mean_resprate  mean_sao2  \
# recordid
# 132539.0         NaN       NaN           203.0      17.428571        NaN
# 132599.0  149.000000  7.478571           228.5            NaN       98.0
# 132599.0  149.000000  7.478571           228.5            NaN       98.0
# 132598.0  190.571429  7.484286           215.5            NaN       98.5
#
#           mean_sysabp  mean_temp  mean_troponint  mean_urine  mean_wbc  \
# recordid
# 132539.0          NaN  37.357143             NaN  171.052632    10.300
# 132599.0   108.923077  37.300000            0.02  105.000000    12.125
# 132599.0   108.923077  37.300000            0.02  105.000000    12.125
# 132598.0   143.591549  37.264706             NaN   62.250000    16.800
#
#           mean_weight  min_albumin  min_alp  min_alt  min_ast  min_bilirubin  \
# recordid
# 132539.0         -1.0          NaN      NaN      NaN      NaN            NaN
# 132599.0         73.5          2.0    112.0     13.0     19.0            1.3
# 132599.0         73.5          2.0    112.0     13.0     19.0            1.3
# 132598.0         60.0          NaN      NaN      NaN      NaN            NaN
#
#           min_bun  min_creatinine  min_diasabp  min_fio2  min_gcs  \
# recordid
# 132539.0      8.0             0.7          NaN       NaN     14.0
# 132599.0     12.0             0.5         55.0       0.4      7.0
# 132599.0     12.0             0.5         55.0       0.4      7.0
# 132598.0     19.0             0.7         42.0       0.4      6.0
#
#           min_glucose  min_hco3  min_hct  min_hr  min_k  min_lactate  min_map  \
# recordid
# 132539.0        115.0      26.0     30.3    58.0    4.0          NaN      NaN
# 132599.0         94.0      21.0     23.2    67.0    3.6          1.3     67.0
# 132599.0         94.0      21.0     23.2    67.0    3.6          1.3     67.0
# 132598.0        129.0      21.0     32.8    49.0    3.3          NaN     54.0
#
#           min_mechvent  min_mg  min_na  min_nidiasabp  min_nimap  \
# recordid
# 132539.0           NaN     1.5   136.0           39.0      58.67
# 132599.0           1.0     1.8   136.0           57.0      74.00
# 132599.0           1.0     1.8   136.0           57.0      74.00
# 132598.0           1.0     1.6   136.0           43.0      58.00
#
#           min_nisysabp  min_paco2  min_pao2  min_ph  min_platelets  \
# recordid
# 132539.0          96.0        NaN       NaN     NaN          185.0
# 132599.0         104.0       28.0      99.0    7.45          196.0
# 132599.0         104.0       28.0      99.0    7.45          196.0
# 132598.0          86.0       25.0     126.0    7.44          185.0
#
#           min_resprate  min_sao2  min_sysabp  min_temp  min_troponint  \
# recordid
# 132539.0          12.0       NaN         NaN      35.1            NaN
# 132599.0           NaN      98.0        86.0      36.2           0.02
# 132599.0           NaN      98.0        86.0      36.2           0.02
# 132598.0           NaN      98.0        74.0      34.2            NaN
#
#           min_urine  min_wbc  min_weight
# recordid
# 132539.0        0.0      9.4        -1.0
# 132599.0       45.0      9.4        73.5
# 132599.0       45.0      9.4        73.5
# 132598.0       15.0     13.4        60.0

# %%
main.groupby(['age','gender']).median()
# Out:
#              first_bun  first_creatinine  first_gcs  first_glucose  \
# age  gender
# 53.0 0.0           NaN               NaN        NaN            NaN
# 54.0 0.0          13.0               0.8       15.0          205.0
# 80.0 0.0           NaN               NaN        NaN            NaN
#
#              first_hco3  first_hct  first_hr  first_k  first_mg  first_na  \
# age  gender
# 53.0 0.0            NaN        NaN       NaN      NaN       NaN       NaN
# 54.0 0.0           26.0       33.7      73.0      4.4       1.5     137.0
# 80.0 0.0            NaN        NaN       NaN      NaN       NaN       NaN
#
#              first_nidiasabp  first_nimap  first_nisysabp  first_platelets  \
# age  gender
# 53.0 0.0                 NaN          NaN             NaN              NaN
# 54.0 0.0                65.0        92.33           147.0            221.0
# 80.0 0.0                 NaN          NaN             NaN              NaN
#
#              first_resprate  first_temp  first_urine  first_wbc  first_weight  \
# age  gender
# 53.0 0.0                NaN         NaN          NaN        NaN           NaN
# 54.0 0.0               19.0        35.1        900.0       11.2          -1.0
# 80.0 0.0                NaN         NaN          NaN        NaN           NaN
#
#              height  icutype  last_bun  last_creatinine  last_gcs  \
# age  gender
# 53.0 0.0      177.8      4.0       NaN              NaN       NaN
# 54.0 0.0       -1.0      4.0       8.0              0.7      15.0
# 80.0 0.0       -1.0      4.0       NaN              NaN       NaN
#
#              last_glucose  last_hco3  last_hct  last_hr  last_k  last_mg  \
# age  gender
# 53.0 0.0              NaN        NaN       NaN      NaN     NaN      NaN
# 54.0 0.0            115.0       28.0      30.3     86.0     4.0      1.9
# 80.0 0.0              NaN        NaN       NaN      NaN     NaN      NaN
#
#              last_na  last_nidiasabp  last_nimap  last_nisysabp  \
# age  gender
# 53.0 0.0         NaN             NaN         NaN            NaN
# 54.0 0.0       136.0            55.0       79.33          128.0
# 80.0 0.0         NaN             NaN         NaN            NaN
#
#              last_platelets  last_resprate  last_temp  last_urine  last_wbc  \
# age  gender
# 53.0 0.0                NaN            NaN        NaN         NaN       NaN
# 54.0 0.0              185.0           23.0       37.8       280.0       9.4
# 80.0 0.0                NaN            NaN        NaN         NaN       NaN
#
#              last_weight  max_albumin  max_alp  max_alt  max_ast  \
# age  gender
# 53.0 0.0             NaN          2.0    124.0     14.0     20.0
# 54.0 0.0            -1.0          NaN      NaN      NaN      NaN
# 80.0 0.0             NaN          NaN      NaN      NaN      NaN
#
#              max_bilirubin  max_bun  max_creatinine  max_diasabp  max_fio2  \
# age  gender
# 53.0 0.0               2.0     33.0             1.0         83.0       1.0
# 54.0 0.0               NaN     13.0             0.8          NaN       NaN
# 80.0 0.0               NaN     30.0             1.0         98.0       1.0
#
#              max_gcs  max_glucose  max_hco3  max_hct  max_hr  max_k  \
# age  gender
# 53.0 0.0        14.0        150.0      23.0     26.8   104.0    3.7
# 54.0 0.0        15.0        205.0      28.0     33.7    86.0    4.4
# 80.0 0.0         8.0        201.0      28.0     40.9   158.0    4.0
#
#              max_lactate  max_map  max_mechvent  max_mg  max_na  \
# age  gender
# 53.0 0.0             2.1    102.0           1.0     2.3   139.0
# 54.0 0.0             NaN      NaN           NaN     1.9   137.0
# 80.0 0.0             NaN    132.0           1.0     2.3   146.0
#
#              max_nidiasabp  max_nimap  max_nisysabp  max_paco2  max_pao2  \
# age  gender
# 53.0 0.0              69.0      86.00         119.0       38.0     184.0
# 54.0 0.0              67.0      92.33         157.0        NaN       NaN
# 80.0 0.0             115.0     127.30         176.0       31.0     364.0
#
#              max_ph  max_platelets  max_resprate  max_sao2  max_sysabp  \
# age  gender
# 53.0 0.0       7.51          255.0           NaN      98.0       145.0
# 54.0 0.0        NaN          221.0          24.0       NaN         NaN
# 80.0 0.0       7.52          246.0           NaN      99.0       208.0
#
#              max_temp  max_troponint  max_urine  max_wbc  max_weight  \
# age  gender
# 53.0 0.0         38.6           0.02      400.0     14.2        73.5
# 54.0 0.0         38.2            NaN      900.0     11.2        -1.0
# 80.0 0.0         39.4            NaN      400.0     20.2        60.0
#
#              mean_albumin    mean_alp   mean_alt   mean_ast  mean_bilirubin  \
# age  gender
# 53.0 0.0              2.0  117.333333  13.333333  19.666667        1.633333
# 54.0 0.0              NaN         NaN        NaN        NaN             NaN
# 80.0 0.0              NaN         NaN        NaN        NaN             NaN
#
#               mean_bun  mean_creatinine  mean_diasabp  mean_fio2   mean_gcs  \
# age  gender
# 53.0 0.0     23.250000         0.650000     67.557692    0.56000   8.416667
# 54.0 0.0     10.500000         0.750000           NaN        NaN  14.923077
# 80.0 0.0     23.666667         0.833333     68.464789    0.49375   7.173913
#
#              mean_glucose  mean_hco3  mean_hct    mean_hr  mean_k  \
# age  gender
# 53.0 0.0       109.500000  22.000000     25.15  85.392857   3.675
# 54.0 0.0       160.000000  27.000000     32.50  70.810811   4.200
# 80.0 0.0       156.333333  23.333333     36.85  78.708861   3.675
#
#              mean_lactate   mean_map  mean_mechvent   mean_mg     mean_na  \
# age  gender
# 53.0 0.0              1.8  82.788462            1.0  2.050000  137.000000
# 54.0 0.0              NaN        NaN            NaN  1.700000  136.500000
# 80.0 0.0              NaN  95.478873            1.0  2.033333  142.666667
#
#              mean_nidiasabp  mean_nimap  mean_nisysabp  mean_paco2  \
# age  gender
# 53.0 0.0          63.000000   79.500000     109.000000   32.142857
# 54.0 0.0          50.147059   71.559118     114.382353         NaN
# 80.0 0.0          66.767442   89.037674     133.581395   28.285714
#
#               mean_pao2   mean_ph  mean_platelets  mean_resprate  mean_sao2  \
# age  gender
# 53.0 0.0     149.000000  7.478571           228.5            NaN       98.0
# 54.0 0.0            NaN       NaN           203.0      17.428571        NaN
# 80.0 0.0     190.571429  7.484286           215.5            NaN       98.5
#
#              mean_sysabp  mean_temp  mean_troponint  mean_urine  mean_wbc  \
# age  gender
# 53.0 0.0      108.923077  37.300000            0.02  105.000000    12.125
# 54.0 0.0             NaN  37.357143             NaN  171.052632    10.300
# 80.0 0.0      143.591549  37.264706             NaN   62.250000    16.800
#
#              mean_weight  min_albumin  min_alp  min_alt  min_ast  \
# age  gender
# 53.0 0.0            73.5          2.0    112.0     13.0     19.0
# 54.0 0.0            -1.0          NaN      NaN      NaN      NaN
# 80.0 0.0            60.0          NaN      NaN      NaN      NaN
#
#              min_bilirubin  min_bun  min_creatinine  min_diasabp  min_fio2  \
# age  gender
# 53.0 0.0               1.3     12.0             0.5         55.0       0.4
# 54.0 0.0               NaN      8.0             0.7          NaN       NaN
# 80.0 0.0               NaN     19.0             0.7         42.0       0.4
#
#              min_gcs  min_glucose  min_hco3  min_hct  min_hr  min_k  \
# age  gender
# 53.0 0.0         7.0         94.0      21.0     23.2    67.0    3.6
# 54.0 0.0        14.0        115.0      26.0     30.3    58.0    4.0
# 80.0 0.0         6.0        129.0      21.0     32.8    49.0    3.3
#
#              min_lactate  min_map  min_mechvent  min_mg  min_na  \
# age  gender
# 53.0 0.0             1.3     67.0           1.0     1.8   136.0
# 54.0 0.0             NaN      NaN           NaN     1.5   136.0
# 80.0 0.0             NaN     54.0           1.0     1.6   136.0
#
#              min_nidiasabp  min_nimap  min_nisysabp  min_paco2  min_pao2  \
# age  gender
# 53.0 0.0              57.0      74.00         104.0       28.0      99.0
# 54.0 0.0              39.0      58.67          96.0        NaN       NaN
# 80.0 0.0              43.0      58.00          86.0       25.0     126.0
#
#              min_ph  min_platelets  min_resprate  min_sao2  min_sysabp  \
# age  gender
# 53.0 0.0       7.45          196.0           NaN      98.0        86.0
# 54.0 0.0        NaN          185.0          12.0       NaN         NaN
# 80.0 0.0       7.44          185.0           NaN      98.0        74.0
#
#              min_temp  min_troponint  min_urine  min_wbc  min_weight
# age  gender
# 53.0 0.0         36.2           0.02       45.0      9.4        73.5
# 54.0 0.0         35.1            NaN        0.0      9.4        -1.0
# 80.0 0.0         34.2            NaN       15.0     13.4        60.0

# %%
for col in main.columns:
    print col
# Out:
# age
# first_bun
# first_creatinine
# first_gcs
# first_glucose
# first_hco3
# first_hct
# first_hr
# first_k
# first_mg
# first_na
# first_nidiasabp
# first_nimap
# first_nisysabp
# first_platelets
# first_resprate
# first_temp
# first_urine
# first_wbc
# first_weight
# gender
# height
# icutype
# last_bun
# last_creatinine
# last_gcs
# last_glucose
# last_hco3
# last_hct
# last_hr
# last_k
# last_mg
# last_na
# last_nidiasabp
# last_nimap
# last_nisysabp
# last_platelets
# last_resprate
# last_temp
# last_urine
# last_wbc
# last_weight
# max_albumin
# max_alp
# max_alt
# max_ast
# max_bilirubin
# max_bun
# max_creatinine
# max_diasabp
# max_fio2
# max_gcs
# max_glucose
# max_hco3
# max_hct
# max_hr
# max_k
# max_lactate
# max_map
# max_mechvent
# max_mg
# max_na
# max_nidiasabp
# max_nimap
# max_nisysabp
# max_paco2
# max_pao2
# max_ph
# max_platelets
# max_resprate
# max_sao2
# max_sysabp
# max_temp
# max_troponint
# max_urine
# max_wbc
# max_weight
# mean_albumin
# mean_alp
# mean_alt
# mean_ast
# mean_bilirubin
# mean_bun
# mean_creatinine
# mean_diasabp
# mean_fio2
# mean_gcs
# mean_glucose
# mean_hco3
# mean_hct
# mean_hr
# mean_k
# mean_lactate
# mean_map
# mean_mechvent
# mean_mg
# mean_na
# mean_nidiasabp
# mean_nimap
# mean_nisysabp
# mean_paco2
# mean_pao2
# mean_ph
# mean_platelets
# mean_resprate
# mean_sao2
# mean_sysabp
# mean_temp
# mean_troponint
# mean_urine
# mean_wbc
# mean_weight
# min_albumin
# min_alp
# min_alt
# min_ast
# min_bilirubin
# min_bun
# min_creatinine
# min_diasabp
# min_fio2
# min_gcs
# min_glucose
# min_hco3
# min_hct
# min_hr
# min_k
# min_lactate
# min_map
# min_mechvent
# min_mg
# min_na
# min_nidiasabp
# min_nimap
# min_nisysabp
# min_paco2
# min_pao2
# min_ph
# min_platelets
# min_resprate
# min_sao2
# min_sysabp
# min_temp
# min_troponint
# min_urine
# min_wbc
# min_weight

# %%
#wide_result.reset_index(inplace=True)
#wide_result.drop('index',axis=1,inplace=True)

# %%
# Pivot_table to convert from long to wide dataset

#wide_result = pd.pivot_table(results,values=['Value'],columns='Parameter',index=['Time'])

#wide_result.columns = wide_result.columns.droplevel(level=0)
#wide_result.reset_index(inplace=True)

# %%
# Trying to convert time to an 'aggreable' data type

#def str_time2(time):
 #   hours, minutes = map(int, time.split(':'))
  #  time = (hours,minutes)
    
   # return time

#def str_time(time):
 #   hours, minutes = map(int, time.split(':'))
  #  time = time.format(int(hours),int(minutes))
   # return time

#for time in wide_result.index:
 #   hours, minutes = map(int, time.split(':'))
  #  time = (hours,minutes)
   # print time
    
#wide_result.Time = wide_result.Time.apply(str_time)

# %%
#class patient_details(object):
 #   """Run description of the patient when admitted on the 48th hour"""
    
  #  def __init__(self,df = wide_result):
         
   #     self.record_id = df[df.Time == '00:00']['RecordID'][0]
    #    self.age = df[df.Time == '00:00']['Age'][0]
     #   self.gender = df[df.Time == '00:00']['Gender'][0]
      #  self.height = df[df.Time == '00:00']['Height'][0]
       # self.ICUtype = df[df.Time == '00:00']['ICUType'][0]

        
        
  #  def fill(self,df = wide_result,details='RecordID'):
   #     """Filling of the NaN values with patient's details can be automated 
    #    by specifying the descriptor(column) in **kwargs """
     #   """Default set as RecordID"""
        
      #  wide_result[details].fillna(value=df[df.Time == '00:00'][details][0],inplace=True)

# %%
# Initiate the class patient_details
#patient = patient_details()

# Fill NaN values in respective descriptor columns
#patient.fill()
#patient.fill(details='Age')
#patient.fill(details='Gender')
#patient.fill(details='Height')
#patient.fill(details='ICUType')

# %%
# change all column names to lower key
#wide_result.columns = wide_result.columns.str.lower()

# %%
# Connect to database

conn = psycopg2.connect(host="localhost",dbname="mortality")
cur = conn.cursor()

# %% [markdown]
# ## EDA
#
# ### 1. Check if the data is unbalanced

# %%
# Open outcomes file

with open('./training_outcomes_a.txt') as outcomefile:
    
    # Open file in list of list
    
    outcome = list(csv.reader(outcomefile))
    
outcome = pd.DataFrame(outcome[1:],columns=outcome[0])    # Convert list of list to DataFrame
outcome = outcome.astype(float,'ignore')    # Change values to float

# %%
# Count the number of positives in dataset
# Positives = 1 = Death, Negative = 0 = Survived

def imbalance_check(column,labels):
    """labels can be a list or a tuple."""
    
    for x in labels:
        label = float(column[column == x].count())
        total = float(column.count())
        
        percentage = float((label/total)*100)
        
        print 'percentage of',x,'in dataset:',percentage,'%'

# %%
imbalance_check(outcome['In-hospital_death'],[0,1])    # Conclude that this is an imbalanced dataset
# Out:
# percentage of 0 in dataset: 86.15 %
# percentage of 1 in dataset: 13.85 %

# %% [markdown]
# ### 2. Create outcomes table in database

# %%
outcome.head(5)
# Out:
#    RecordID  SAPS-I  SOFA  Length_of_stay  Survival  In-hospital_death
# 0  132539.0     6.0   1.0             5.0      -1.0                0.0
# 1  132540.0    16.0   8.0             8.0      -1.0                0.0
# 2  132541.0    21.0  11.0            19.0      -1.0                0.0
# 3  132543.0     7.0   1.0             9.0     575.0                0.0
# 4  132545.0    17.0   2.0             4.0     918.0                0.0

# %%
pd.to_sql()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-3d655a560942> in <module>()
# ----> 1 pd.to_sql()
#
# AttributeError: 'module' object has no attribute 'to_sql'
